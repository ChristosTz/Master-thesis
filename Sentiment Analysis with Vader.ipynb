# %%
import numpy as np
import pandas as pd

# %%
pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in c:\users\xrist\anaconda3\lib\site-packages (3.3.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\xrist\anaconda3\lib\site-packages (from vaderSentiment) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xrist\anaconda3\lib\site-packages (from requests->vaderSentiment) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\xrist\anaconda3\lib\site-packages (from requests->vaderSentiment) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xrist\anaconda3\lib\site-packages (from requests->vaderSentiment) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xrist\anaconda3\lib\site-packages (from requests->vaderSentiment) (1.26.11)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
SA = SentimentIntensityAnalyzer()

# %%
df = pd.read_csv("pos tags, counts, emotiveness.csv")

# %%
#Sentiment analysis
sa = []
for idx,x in enumerate(df['title']):
    sa.append(SA.polarity_scores(x))

# %%
#Create sentiment labels
negative = pd.DataFrame([d['neg'] for d in sa])
positive = pd.DataFrame([d['pos'] for d in sa])
neutral = pd.DataFrame([d['neu'] for d in sa])
compound = pd.DataFrame([d['compound'] for d in sa])
#Attach sentiment labels
df['compound'] = compound
df['positive'] = positive
df['negative'] = negative
df['neutral'] = neutral

# %%
df
# Out:
#                                                    title  label  \
# 0      As U.S. budget fight looms, Republicans flip t...      0
# 1      U.s. military to accept Transgender recruits o...      0
# 2      Senior U.S. Republican Senator: 'Let Mr. Muell...      0
# 3      Fbi Russia probe helped by Australian diplomat...      0
# 4      Trump wants postal service to charge 'Much mor...      0
# ...                                                  ...    ...
# 44893  Mcpain: John McCain furious that Iran treated ...      1
# 44894  Justice? Yahoo settles E-mail privacy class-ac...      1
# 44895  Sunnistan: us and Allied ‘ safe zone ’ plan to...      1
# 44896  How to blow $700 million: al Jazeera America f...      1
# 44897  10 U.S. Navy sailors held by Iranian military ...      1
#
#                                               token_data  \
# 0      ['As', 'U.S.', 'budget', 'fight', 'looms', ','...
# 1      ['U.s.', 'military', 'to', 'accept', 'Transgen...
# 2      ['Senior', 'U.S.', 'Republican', 'Senator', ':...
# 3      ['Fbi', 'Russia', 'probe', 'helped', 'by', 'Au...
# 4      ['Trump', 'wants', 'postal', 'service', 'to', ...
# ...                                                  ...
# 44893  ['Mcpain', ':', 'John', 'McCain', 'furious', '...
# 44894  ['Justice', '?', 'Yahoo', 'settles', 'E-mail',...
# 44895  ['Sunnistan', ':', 'us', 'and', 'Allied', '‘',...
# 44896  ['How', 'to', 'blow', '$', '700', 'million', '...
# 44897  ['10', 'U.S.', 'Navy', 'sailors', 'held', 'by'...
#
#                                                      tag  \
# 0      [('As', 'IN'), ('U.S.', 'NNP'), ('budget', 'NN...
# 1      [('U.s.', 'JJ'), ('military', 'JJ'), ('to', 'T...
# 2      [('Senior', 'JJ'), ('U.S.', 'NNP'), ('Republic...
# 3      [('Fbi', 'NNP'), ('Russia', 'NNP'), ('probe', ...
# 4      [('Trump', 'NN'), ('wants', 'VBZ'), ('postal',...
# ...                                                  ...
# 44893  [('Mcpain', 'NN'), (':', ':'), ('John', 'NNP')...
# 44894  [('Justice', 'NNP'), ('?', '.'), ('Yahoo', 'NN...
# 44895  [('Sunnistan', 'NN'), (':', ':'), ('us', 'PRP'...
# 44896  [('How', 'WRB'), ('to', 'TO'), ('blow', 'VB'),...
# 44897  [('10', 'CD'), ('U.S.', 'NNP'), ('Navy', 'NNP'...
#
#                                                 features  word_count  \
# 0      [{'As': 'IN', 'U.S.': 'NNP', 'budget': 'NN', '...          10
# 1      [{'U.s.': 'JJ', 'military': 'JJ', 'to': 'TO', ...           9
# 2      [{'Senior': 'JJ', 'U.S.': 'NNP', 'Republican':...          11
# 3      [{'Fbi': 'NNP', 'Russia': 'NNP', 'probe': 'NN'...           9
# 4      [{'Trump': 'NN', 'wants': 'VBZ', 'postal': 'JJ...          11
# ...                                                  ...         ...
# 44893  [{'Mcpain': 'NN', ':': ':', 'John': 'NNP', 'Mc...          10
# 44894  [{'Justice': 'NNP', '?': '.', 'Yahoo': 'NNP', ...          12
# 44895  [{'Sunnistan': 'NN', ':': ':', 'us': 'PRP', 'a...          16
# 44896  [{'How': 'WRB', 'to': 'TO', 'blow': 'VB', '$':...          12
# 44897  [{'10': 'CD', 'U.S.': 'NNP', 'Navy': 'NNP', 's...          15
#
#        modal_count  verb_count  adjective_count  adverb_count  \
# 0                0           2                1             0
# 1                0           1                2             0
# 2                0           1                1             0
# 3                0           1                1             0
# 4                0           2                1             2
# ...            ...         ...              ...           ...
# 44893            0           1                1             1
# 44894            0           1                0             0
# 44895            0           1                3             0
# 44896            0           3                0             1
# 44897            0           1                3             0
#
#        proper_noun_count  noun_count  emotiveness  modifiers  compound  \
# 0                      2           3     0.200000          1   -0.4939
# 1                      3           1     1.000000          2    0.3818
# 2                      5           1     0.500000          1    0.0000
# 3                      2           4     0.200000          1    0.0000
# 4                      1           3     0.600000          3    0.2449
# ...                  ...         ...          ...        ...       ...
# 44893                  3           2     0.666667          2   -0.3818
# 44894                  3           4     0.000000          0    0.5267
# 44895                  3           5     0.500000          3    0.4404
# 44896                  2           1     0.250000          1    0.0000
# 44897                  3           4     0.600000          3    0.0000
#
#        positive  negative  neutral
# 0         0.000     0.344    0.656
# 1         0.245     0.000    0.755
# 2         0.000     0.000    1.000
# 3         0.000     0.000    1.000
# 4         0.165     0.000    0.835
# ...         ...       ...      ...
# 44893     0.152     0.268    0.580
# 44894     0.236     0.000    0.764
# 44895     0.162     0.000    0.838
# 44896     0.000     0.000    1.000
# 44897     0.000     0.000    1.000
#
# [44898 rows x 18 columns]

# %%
df.to_csv('dataset with sentiment.csv', index = False)
